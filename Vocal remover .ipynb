# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.io.wavfile
import urllib

from IPython.display import Audio
import pytest
import os

#url = "https://universityofcambridgecloud-my.sharepoint.com/:u:/r/personal/tb267_cam_ac_uk/Documents/Students%202018-2019/General%20Resources/sample.wav?csf=1&e=fYOAZl"
#Audio(url)

import os

# %%
f = "sample.wav"

# Read frequency and data array for sound track
fs, x = scipy.io.wavfile.read(f) 

#seperate left and right channels
x1 = x[:, 0]
x2 = x[:, 1]

#merge left and inverted right channel to remove vocals
x = x1 -x2
# play
Audio(x, rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
